# %%
import seaborn as sns

# Load the Iris dataset
iris_data = sns.load_dataset('iris')

# Inspect the dataset
print(iris_data.head())
print(iris_data.info())
print(iris_data.describe())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %%
import matplotlib.pyplot as plt
# Use a Seaborn color palette for Matplotlib
sns.set_palette('tab10')  

# Histogram for sepal width
plt.figure(figsize=(8, 6))
plt.hist(iris_data['sepal_width'], bins=10, color=sns.color_palette('tab10')[-1], edgecolor='black')
plt.title('Distribution of Sepal Width', fontsize=14)
plt.xlabel('Sepal Width (cm)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
